# %% [markdown]
# ## Distribution

# %% [markdown]
# Gaussian/Normal Distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above figure also show Empirical rule, so what is emirical rule?
# - The empirical rule, also sometimes called the three-sigma or 68-95-99.7 rule, is a statistical rule which states that for normally distributed data, almost all observed data will fall within three standard deviation.
# - In particular, the empirical rule predicts that in normal distributions, 68% of observations fall within the first standard deviation (µ ± σ), 95% within the first two standard deviations (µ ± 2σ), and 99.7% within the first three standard deviations (µ ± 3σ) of the mean.

# %% [markdown]
# Example: Generally height and weight follow gaussian distribution

# %% [markdown]
# ## Z score

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Actual use of z score?

# %% [markdown]
# The z-score is a statistical measure that helps us understand how far a data point is from the mean of a population, expressed in terms of standard deviations.

# %% [markdown]
# How many standard deviation to the right and left, if arise - remember, we need to find z score

# %% [markdown]
# Suppose, if we apply z score to our normally distributed data, it will basically convert or standardized it to standard normal distribution, whose mean is zero and standard deviation will be 1.

# %% [markdown]
# Suppose we have data:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if we use this above formula: we get standard score for each column:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example (What percentage of score fall above 4.25?)
# ![image.png](attachment:image.png)

# %% [markdown]
# Firstly, find z score and check on z table

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 0.25 means in z table?  (see left tail)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here, mean is 100, standard deviation is 15 and x is 85, lets find z score = -1, here we can get ans 15% approx

# %% [markdown]
# EXAMPLE:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df["total_bill"])
# Out:
# 19.78594262295082

# %%
np.median(df["total_bill"])
# Out:
# 17.795

# %%
import statistics

# %%
statistics.mode(df["total_bill"])
# Out:
# 13.42

# %%
statistics.median(df["total_bill"])
# Out:
# 17.795

# %%
sns.boxplot(df["total_bill"], orient='h')
# Out:
# <Axes: >

# %%
sns.histplot(df["total_bill"],kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# Is it bell or Guassian curve? No, so we can convert it in Normal distribution, its sekewed towards right.

# %% [markdown]
# We can find percentile too, lets see:

# %%
np.percentile(df["total_bill"],[25,75])
# Out:
# array([13.3475, 24.1275])

# %% [markdown]
# So, what is IQR= 24.1275-13.3475

# %% [markdown]
# Now, lets try to convert above total bill standardization: which will be useful for ML later while predicting

# %%
# Lets find standard deviation and mean first? Just to check and compare

np.mean(df["total_bill"])
# Out:
# 19.78594262295082

# %%
np.std(df["total_bill"])
# Out:
# 8.88415057777113

# %% [markdown]
# Now lets do standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# %%
# Fit and transform the 'total_bill' column
df['total_bill_standardized'] = scaler.fit_transform(df[['total_bill']])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_standardized
# 0       16.99  1.01  Female     No  Sun  Dinner     2                -0.314711
# 1       10.34  1.66    Male     No  Sun  Dinner     3                -1.063235
# 2       21.01  3.50    Male     No  Sun  Dinner     3                 0.137780
# 3       23.68  3.31    Male     No  Sun  Dinner     2                 0.438315
# 4       24.59  3.61  Female     No  Sun  Dinner     4                 0.540745

# %%
np.round(np.mean(df['total_bill_standardized']))
# Out:
# -0.0

# %%
np.std(df['total_bill_standardized'])
# Out:
# 0.9999999999999999

# %% [markdown]
# Here above we can see doing standarization, mean is 0 and standar deviation is approx 1.

# %% [markdown]
# Guassian curve after standardization:

# %%
sns.histplot(df['total_bill_standardized'],kde=True)
# Out:
# <Axes: xlabel='total_bill_standardized', ylabel='Count'>

# %% [markdown]
# Now see, data come in standard format but way and character od data have not changed, this is most important part of standardization, this is very useful technique during ML process during prediction and fitting ML model.
